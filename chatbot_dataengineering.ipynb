# %%
# !pip install mysql-connector-python -q

import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
      host="146.190.146.6",
      port=3306,
      user="estudiante_sql",
      password="Academia100%",
      database="estudiantes_sql"
)

print("Conectado al servidor")

tablas = pd.read_sql("SHOW TABLES", conn)
print(tablas)

df = pd.read_sql("SELECT * FROM estudiantes LIMIT 5", conn)
print(df)

schema = pd.read_sql("DESCRIBE estudiantes", conn)
print(schema)

conn.close()
# Out:
# Conectado al servidor
# /tmp/ipykernel_3292/2859677285.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tablas = pd.read_sql("SHOW TABLES", conn)
# /tmp/ipykernel_3292/2859677285.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM estudiantes LIMIT 5", conn)
# /tmp/ipykernel_3292/2859677285.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   schema = pd.read_sql("DESCRIBE estudiantes", conn)
#    Tables_in_estudiantes_sql
# 0                estudiantes
# 1         historial_entregas
# 2                    pedidos
# 3                 pedidos_OP
# 4                 pedidos_ad
# 5                pedidos_app
# 6              pedidos_cesar
# 7                 pedidos_la
# 8        productos_comida_ce
# 9         productos_shein_ad
# 10     productos_shein_cesar
# 11        productos_shein_ke
# 12        productos_shein_la
# 13        proveedores_sql_Op
# 14             publicaciones
# 15            seg_pendientes
# 16       usuario_nequi_cesar
# 17                  usuarios
# 18               usuarios_OP
# 19               usuarios_la
#    id   nombre      apellido
# 0   1    Cesar       comepan
# 1   2  Adriana     Risueñita
# 2   3     Omar     butifarra
# 3   4    Laura  Saltacharcos
# 4   5   prueba        prueba
#       Field         Type Null  Key Default           Extra
# 0        id          int   NO  PRI    None  auto_increment
# 1    nombre  varchar(50)   NO         None
# 2  apellido  varchar(80)   NO         None

# %%
# Paso 1: Conseguir API key gratis
# → ve a console.groq.com
# → Sign up con tu correo (sin tarjeta)
# → API Keys → Create API Key → copiar

# Paso 2: Instalar en Colab
# !pip install groq -q

# Paso 3: Primera llamada
from groq import Groq

cliente = Groq(api_key="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")

respuesta = cliente.chat.completions.create(
    model="llama-3.1-8b-instant",  # gratis y rápido
    messages=[
        {
            "role": "system",
            "content": "Eres un analista de datos experto. Responde siempre en español claro y conciso."
        },
        {
            "role": "user",
            "content": "¿Cuáles son las 3 preguntas más importantes que debería hacerle a mis datos de ventas?"
        }
    ],
    temperature=0.3,
    max_tokens=500
)

# La respuesta está aquí
texto = respuesta.choices[0].message.content
print(texto)

# Cuántos tokens usaste
print(f"Tokens usados: {respuesta.usage.total_tokens}")
# Out:
# Como analista de datos, te recomiendo hacer las siguientes tres preguntas a tus datos de ventas:
#
# 1. **¿Cuáles son los productos o servicios más rentables?**: Esto te ayudará a identificar qué productos o servicios generan más ingresos y a concentrar tus esfuerzos en promocionarlos y optimizar su precio y oferta.
#
# 2. **¿Cuáles son los canales de venta más efectivos?**: Esto te ayudará a entender cómo se están realizando las ventas y a identificar los canales más efectivos, como la web, las redes sociales, el correo electrónico o las ventas directas.
#
# 3. **¿Cuáles son los clientes más valiosos y cómo podemos retenerlos?**: Esto te ayudará a identificar a los clientes que generan más ingresos y a entender qué factores los hacen valiosos. Puedes analizar su comportamiento, sus preferencias y sus necesidades para desarrollar estrategias de retención y fidelización.
#
# Estas preguntas te permitirán obtener una visión clara de tus datos de ventas y tomar decisiones informadas para mejorar tus resultados.
# Tokens usados: 325

# %%
#instalar
# !pip install groq -q


from groq import Groq

cliente = Groq(api_key="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")

# Historial del chat
mensajes = [
    {
        "role": "system",
        "content": "Eres un analista de datos experto. Responde siempre en español claro y conciso."
    }
]

print("Chat iniciado.")
print("Escribe 'salir' para terminar.\n")

while True:
    pregunta = input("Tú: ")

    if pregunta.lower() == "salir":
        print("Chat finalizado.")
        break

    mensajes.append({
        "role": "user",
        "content": pregunta
    })

    respuesta = cliente.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=mensajes,
        temperature=0.3,
        max_tokens=500
    )

    texto = respuesta.choices[0].message.content

    mensajes.append({
        "role": "assistant",
        "content": texto
    })

    print("\nModelo:")
    print(texto)
    print(f"\nTokens usados: {respuesta.usage.total_tokens}")
    print("-" * 50)
# Out:
# Chat iniciado.
# Escribe 'salir' para terminar.
#
#
# Modelo:
# El nombre "César" tiene una rica historia y se originó en la antigua Roma. El nombre se deriva del cognomen "Caesar", que era un apodo utilizado por la familia patricia de los Julios.
#
# El nombre "César" se asocia principalmente con Julio César, un líder político y militar romano que vivió en el siglo I a.C. y fue uno de los personajes más influyentes de la historia de Roma. Fue nombrado dictador de Roma en 49 a.C. y se convirtió en una figura legendaria en la historia romana.
#
# El nombre "César" se popularizó en Europa durante la Edad Media, especialmente después de la caída del Imperio Romano. En la Edad Media, el nombre "César" se utilizaba como un título de nobleza y se asociaba con la autoridad y el poder.
#
# En la actualidad, el nombre "César" es común en muchos países de habla hispana y se utiliza tanto para hombres como para mujeres. En algunos países, como Francia, el nombre "César" se utiliza como un nombre propio y se asocia con la tradición y la historia.
#
# En resumen, el nombre "César" tiene sus raíces en la antigua Roma y se originó en la familia patricia de los Julios. Se popularizó en Europa durante la Edad Media y se utiliza actualmente en muchos países de habla hispana como un nombre propio y un título de nobleza.
#
# Tokens usados: 405
# --------------------------------------------------
